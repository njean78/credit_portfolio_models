# %%
import datetime
import numpy as np
import sys, os
sys.path.append('../../chart')
sys.path.append('../../creditmodels')

# %%
from SecondOrderGranularityAdj import portfolio
reload(portfolio)
# Out:
# <module 'SecondOrderGranularityAdj.portfolio' from '../../creditmodels/SecondOrderGranularityAdj/portfolio.pyc'>

# %%
num_of_credits = 40
default_probability = 0.01
correlation = 0.2 
loss_given_default = 1.0
x_list = np.arange(0.02, 0.30, 0.005)
y_list = np.arange(0.994, 0.999, 0.001)

# %%
data_var = portfolio.main_var(num_of_credits, default_probability, correlation, loss_given_default, x_list)

# %%
import highcharts_lines as chart
reload(chart)
chart.initialize_highcharts()
chart.create_from_data_series(data_var, title = 'VaR', subtitle = "with different loss percentage",
                              ylabel = ' value ', xlabel = ' loss ', xtype = 'string')
# Out:
#     <script src="http://code.highcharts.com/highcharts.js"></script>
# <div id="chart_E58P7MTMUGAU0M6" style="min-width: 400px; height: 400px; margin: 0 auto">Re-run cell if chart is not shown ...</div>
# <script>
#     do_chart_E58P7MTMUGAU0M6 = function() {
# ...

# %%
data_es = portfolio.main_es(num_of_credits, default_probability, correlation, loss_given_default, x_list, y_list)

# %%
import highcharts_lines as chart
reload(chart)
chart.initialize_highcharts()
chart.create_from_data_series(data_es, title = 'Expected Shortfall', subtitle = "with different loss percentage",
                              ylabel = ' value ', xlabel = ' loss ', xtype = 'string')
# Out:
#     <script src="http://code.highcharts.com/highcharts.js"></script>
# <div id="chart_BK0A7NEYBLJHX20" style="min-width: 400px; height: 400px; margin: 0 auto">Re-run cell if chart is not shown ...</div>
# <script>
#     do_chart_BK0A7NEYBLJHX20 = function() {
# ...
